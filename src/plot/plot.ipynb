# %%
import matplotlib.pyplot as plt

# QSVM
train_test_count = ["50,10", "500,10", "500,100", "500,200", "500,500", "1000,100", "1000,200", "1000,500", "1500,100", "1500,200", "1500,500"]  
train_time = [0.89, 175.75, 177.58, 179.05, 174.16, 688.38, 685.60, 706.07, 1558.37, 1578.38, 1609.10]
test_time = [0.84, 13.83, 151.70, 295.89, 707.59, 282.84, 574.62, 1451.64, 427.20, 886.62, 2236.98]
accuracy = [0.9, 1, 0.74, 0.75, 0.686, 0.75, 0.74, 0.72, 0.75, 0.75, 0.69]
f1_score = [0.9091, 1, 0.7174, 0.7222, 0.6789, 0.7191, 0.6941, 0.6774, 0.7253, 0.7159, 0.6778]

plt.figure(figsize=(12, 4))
plt.plot(train_test_count, train_time, marker='o', label="Training time")
plt.plot(train_test_count, test_time, marker='o', label="Testing time")

plt.xlabel("(#Train, #Test)")
plt.ylabel("Time (seconds)")
plt.title("QSVM")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()


plt.figure(figsize=(12, 4))
plt.plot(train_test_count, accuracy, marker='o', label="Accuracy")
plt.plot(train_test_count, f1_score, marker='o', label="F1-score")

plt.xlabel("(#Train, #Test)")
plt.ylabel("Accuracy and +ve F1 score")
plt.title("QSVM Accuracy")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# QSVM
kernel = ["Linear", "Poly", "RBF", "Sigmoid"]  
train_time = [433.97, 631.46, 112.55, 438.58]
test_time = [10.11, 9.89, 7.16, 16.51]
accuracy = [0.7516412349183819, 0.7665010645848119, 0.7886355571327183, 0.7572303051809794]
f1_score = [0.7402, 0.7587, 0.7868, 0.7489]

plt.figure(figsize=(6, 4))
plt.plot(kernel, train_time, marker='o', label="Training time")
plt.plot(kernel, test_time, marker='o', label="Testing time")

plt.xlabel("Kernel")
plt.ylabel("Time (seconds)")
plt.title("SVM")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()


plt.figure(figsize=(6, 4))
plt.plot(kernel, accuracy, marker='o', label="Accuracy")
plt.plot(kernel, f1_score, marker='o', label="F1-score")

plt.xlabel("Kernel")
plt.ylabel("Accuracy and +ve F1 score")
plt.title("SVM Accuracy")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# QSVM
train_test_count = ["500,100,1", "500,100,12", "500,100,20", "500,100,30", "500,100,40", "500,100,50", "1000,100,12", "1000,100,20", "1000,100,40"]  
train_time = [200.48, 2356.71, 3905.93, 5881.08, 7945.45, 9688.19, 4671.18, 7965.01, 15419.02]
test_time = [0.25, 0.24, 0.24, 0.25, 0.25, 0.24, 0.25, 0.28, 0.24]
accuracy = [0.45, 0.59, 0.55, 0.66, 0.8, 0.62, 0.46, 0.7, 0.8]
f1_score = [0.44, 0.41, 0.31, 0.61, 0.81, 0.50, 0.04, 0.66, 0.79]

plt.figure(figsize=(12, 6))
plt.plot(train_test_count, train_time, marker='o', label="Training time")
plt.plot(train_test_count, test_time, marker='o', label="Testing time")

plt.xlabel("(#Train, #Test, #Epoch)")
plt.ylabel("Time (seconds)")
plt.title("QCNN")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()


plt.figure(figsize=(12, 6))
plt.plot(train_test_count, accuracy, marker='o', label="Accuracy")
plt.plot(train_test_count, f1_score, marker='o', label="F1-score")

plt.xlabel("(#Train, #Test, #Epoch)")
plt.ylabel("Accuracy and +ve F1 score")
plt.title("QCNN Accuracy")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# QSVM
train_test_count = ["50,10,10", "500,10,10", "500,100,10", "500,100,20", "500,100,50", "500,100,100", "500,100,200", "1000,100,10", "1000,100,20", "1000,100,50", "1000,100,200"]  
train_time = [6.24, 61.55, 60.52, 119.61, 307.53, 614.49, 1223.68, 122.36, 242.7, 591.59, 2414.39]
test_time = [0.02, 0.01, 0.07, 0.07, 0.07, 0.07, 0.07, 0.07, 0.07, 0.07, 0.07]
accuracy = [0.3, 0.3, 0.45, 0.45, 0.56, 0.69, 0.68, 0.55, 0.6, 0.66, 0.67]
f1_score = [0.46, 0.46, 0.00, 0.00, 0.55, 0.64, 0.63, 0.71, 0.49, 0.6, 0.62]

plt.figure(figsize=(12, 6))
plt.plot(train_test_count, train_time, marker='o', label="Training time")
plt.plot(train_test_count, test_time, marker='o', label="Testing time")

plt.xlabel("(#Train, #Test, #Epoch)")
plt.ylabel("Time (seconds)")
plt.title("VQC")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()


plt.figure(figsize=(12, 6))
plt.plot(train_test_count, accuracy, marker='o', label="Accuracy")
plt.plot(train_test_count, f1_score, marker='o', label="F1-score")

plt.xlabel("(#Train, #Test, #Epoch)")
plt.ylabel("Accuracy and +ve F1 score")
plt.title("VQC Accuracy")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# QSVM
kernel = ["Decision Tree", "Random Forest", "SVM (rbf)", "K-Means"]  
accuracy = [0.9974, 0.9973, 0.9493, 0.8220]
f1_score = [0.9935, 0.9932, 0.8829, 0.4671]


plt.figure(figsize=(6, 4))
plt.plot(kernel, accuracy, marker='o', label="Accuracy")
plt.plot(kernel, f1_score, marker='o', label="F1-score")

plt.xlabel("Model")
plt.ylabel("Accuracy and +ve F1 score")
plt.title("CIC-IDS Classical Accuracy")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt

# QSVM
kernel = ["VQC", "QCNN", "QSVM", "QK-Means"]  
accuracy = [0.83, 0.81, 0.845, 0.8220]
f1_score = [0.00, 0.49, 0.0, 0.0]


plt.figure(figsize=(6, 4))
plt.plot(kernel, accuracy, marker='o', label="Accuracy")
plt.plot(kernel, f1_score, marker='o', label="F1-Score")

plt.xlabel("Model")
plt.ylabel("Accuracy and +ve F1 score")
plt.title("CIC-IDS Quantum Accuracy")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# QSVM
kernel = ["Decision Tree", "Random Forest", "SVM (rbf)", "K-Means"]  
accuracy = [0.7853087295954577, 0.7648154719659332, 0.7886355571327183, 0.6]
f1_score = [0.7742, 0.7462, 0.7868, 0.8408]


plt.figure(figsize=(6, 4))
plt.plot(kernel, accuracy, marker='o', label="Accuracy")
plt.plot(kernel, f1_score, marker='o', label="F1-score")

plt.xlabel("Model")
plt.ylabel("Accuracy and +ve F1 score")
plt.title("Classical Accuracy")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt

# QSVM
kernel = ["VQC", "QCNN", "QSVM", "QK-Means"]  
accuracy = [0.69, 0.8, 0.75, 0.8480]
f1_score = [0.64, 0.81, 0.7222,  0.8216]


plt.figure(figsize=(6, 4))
plt.plot(kernel, accuracy, marker='o', label="Accuracy")
plt.plot(kernel, f1_score, marker='o', label="F1-score")

plt.xlabel("Model")
plt.ylabel("Accuracy and +ve F1 score")
plt.title("Quantum Accuracy")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# QSVM
kernel = ["500", "600", "1000", "1500", "3000", "5000", "10000"]  
train_time = [0.6447110176086426, 0.7343425750732422, 1.381789207458496, 2.727484941482544, 8.18042254447937, 21.10260820388794, 76.84842038154602]
test_time = [0.003942966461181641, 0.0036792755126953125, 0.004004478454589844, 0.004681587219238281, 0.004467010498046875, 0.004937410354614258, 0.007185459136962891]
accuracy = [0.7780, 0.8283, 0.9040, 0.8480, 0.8627, 0.8700, 0.8676]
f1_score = [0.6975, 0.7968, 0.8998, 0.8216, 0.8310, 0.8411, 0.8418]

plt.figure(figsize=(6, 4))
plt.plot(kernel, train_time, marker='o', label="Training time")
plt.plot(kernel, test_time, marker='o', label="Testing time")

plt.xlabel("Kernel")
plt.ylabel("Time (seconds)")
plt.title("Q K-means")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()


plt.figure(figsize=(6, 4))
plt.plot(kernel, accuracy, marker='o', label="Accuracy")
plt.plot(kernel, f1_score, marker='o', label="F1-score")

plt.xlabel("Kernel")
plt.ylabel("Accuracy and +ve F1 score")
plt.title("Q K-means")

plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
